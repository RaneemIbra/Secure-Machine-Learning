# %%
import os
import cv2
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
import matplotlib.pyplot as plt

# If you haven't installed insightface:
#    pip install insightface opencv-python onnxruntime

import insightface
from insightface.app import FaceAnalysis
import onnxruntime

print("Available ONNXRuntime providers:", onnxruntime.get_available_providers())

# --------------------------------------------------
#               DEVICE + CLEAR CACHE
# --------------------------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device.type == "cuda":
    torch.cuda.empty_cache()
print(f"Using device: {device}")

# --------------------------------------------------
#            DATASET & PATHS
# --------------------------------------------------
# Make sure you have downloaded LFW dataset (lfw-deepfunneled) and
# the pairsDevTrain.txt, pairsDevTest.txt in the 'dataset/lfw-deepfunneled' folder,
# structured similarly to the original LFW directory structure.
base_dir = os.path.join('dataset', 'lfw-deepfunneled', 'lfw-deepfunneled')
pairs_train_path = 'pairsDevTrain.txt'
pairs_test_path = 'pairsDevTest.txt'

def normalize_name(name):
    return name.replace(' ', '_')

def load_pairs(pairs_path, base_dir):
    """
    Parse the LFW pairs file and return a list of (img1_path, img2_path, label).
    label=1 => same person, label=0 => different person.
    """
    pairs = []
    with open(pairs_path, 'r') as f:
        lines = f.readlines()[1:]  # skip header
        for line in lines:
            parts = line.strip().split()
            if len(parts) == 3:  # Positive pair
                person, img1, img2 = parts
                person = normalize_name(person)
                img1_path = os.path.join(base_dir, person, f"{person}_{int(img1):04d}.jpg")
                img2_path = os.path.join(base_dir, person, f"{person}_{int(img2):04d}.jpg")
                if os.path.exists(img1_path) and os.path.exists(img2_path):
                    pairs.append((img1_path, img2_path, 1))
            elif len(parts) == 4:  # Negative pair
                p1, img1, p2, img2 = parts
                p1, p2 = normalize_name(p1), normalize_name(p2)
                img1_path = os.path.join(base_dir, p1, f"{p1}_{int(img1):04d}.jpg")
                img2_path = os.path.join(base_dir, p2, f"{p2}_{int(img2):04d}.jpg")
                if os.path.exists(img1_path) and os.path.exists(img2_path):
                    pairs.append((img1_path, img2_path, 0))
    return pairs

# Load LFW pairs
train_pairs = load_pairs(pairs_train_path, base_dir)
test_pairs = load_pairs(pairs_test_path, base_dir)
all_pairs = train_pairs + test_pairs
print(f"Train pairs: {len(train_pairs)}, Test pairs: {len(test_pairs)}")

# --------------------------------------------------
#   ARCFACE (R100) VIA INSIGHTFACE "buffalo_l"
# --------------------------------------------------
# Note: "buffalo_l" includes a pipeline with detection + recognition
# but we primarily use the 'recognition' submodel for embeddings.
app = FaceAnalysis(name='buffalo_l', 
                   providers=['CUDAExecutionProvider', 'CPUExecutionProvider'])
app.prepare(ctx_id=0, det_size=(112, 112))  # model expects 112x112

def get_arcface_embedding(img_path):
    """
    Loads an image, resizes to 112x112, gets ArcFace embedding, 
    then L2-normalizes and returns as float32 vector of size 512.
    """
    bgr_img = cv2.imread(img_path)
    if bgr_img is None:
        raise ValueError(f"Could not load image: {img_path}")
    bgr_img = cv2.resize(bgr_img, (112, 112))
    rgb_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2RGB)
    recognition_model = app.models['recognition']  # ArcFaceONNX
    feat = recognition_model.get_feat(rgb_img)
    feat_norm = feat / np.linalg.norm(feat)
    return feat_norm.astype(np.float32)

# --------------------------------------------------
#   GENERATE & CACHE EMBEDDINGS
# --------------------------------------------------
def build_embeddings_dict(pairs_list):
    unique_paths = set()
    for (img1, img2, _) in pairs_list:
        unique_paths.add(img1)
        unique_paths.add(img2)
    unique_paths = list(unique_paths)

    emb_dict = {}
    for path in unique_paths:
        emb = get_arcface_embedding(path)  # shape=(512,)
        emb_dict[path] = emb
    return emb_dict

# --------------------------------------------------
#   MLP CLASSIFIER ON abs-diff OF EMBEDDINGS
# --------------------------------------------------
class PairMLP(nn.Module):
    """
    Takes input shape=(N,512) => outputs prob of "same person".
    We feed in the absolute difference between two embeddings 
    (embedding dimension=512).
    """
    def __init__(self, input_dim=512, hidden_dims=[256, 128], dropout=0.3):
        super().__init__()
        layers = []
        prev = input_dim
        for h in hidden_dims:
            layers.append(nn.Linear(prev, h))
            layers.append(nn.BatchNorm1d(h))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Dropout(p=dropout))
            prev = h
        layers.append(nn.Linear(prev, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        # x shape: (batch_size, 512)
        x = x.view(x.size(0), -1)  # Flatten if needed
        return torch.sigmoid(self.net(x))

# --------------------------------------------------
#       FOCAL LOSS (Optional)
# --------------------------------------------------
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.bce = nn.BCELoss(reduction='none')

    def forward(self, preds, targets):
        bce_loss = self.bce(preds, targets)
        pt = torch.exp(-bce_loss)
        focal = self.alpha * (1 - pt) ** self.gamma * bce_loss
        return focal.mean()

# --------------------------------------------------
#   DATASET FOR (abs-diff, label) with custom decimal truncation
# --------------------------------------------------
class DiffLabelDataset(Dataset):
    def __init__(self, pairs_list, emb_dict, decimals=4):
        """
        decimals: number of decimal places to keep in the embeddings.
        """
        super().__init__()
        self.samples = []
        self.decimals = decimals
        scale = 10**decimals if decimals else None

        for (img1, img2, lab) in pairs_list:
            emb1 = emb_dict[img1].copy()
            emb2 = emb_dict[img2].copy()
            # Truncate to desired precision:
            if scale:
                emb1 = np.floor(emb1 * scale) / scale
                emb2 = np.floor(emb2 * scale) / scale
            diff = np.abs(emb1 - emb2).astype(np.float32)
            self.samples.append((diff, float(lab)))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        diff, lab = self.samples[idx]
        return torch.tensor(diff, dtype=torch.float32), torch.tensor(lab, dtype=torch.float32)

# --------------------------------------------------
#        TRAIN MLP ON (diff,label)
# --------------------------------------------------
def train_mlp(
    pair_mlp,
    train_dataset,
    test_dataset,
    epochs=10,
    batch_size=64,
    lr=1e-3,
    alpha=0.25,
    gamma=2.0
):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    pair_mlp.to(device)
    optimizer = optim.Adam(pair_mlp.parameters(), lr=lr)
    criterion = FocalLoss(alpha=alpha, gamma=gamma)

    history = {
        'train_loss': [], 'test_loss': [],
        'train_acc': [], 'test_acc': [],
        'train_auc': [], 'test_auc': []
    }

    for epoch in range(epochs):
        # ---------- TRAIN ----------
        pair_mlp.train()
        total_train, correct_train = 0, 0
        running_loss = 0.0
        y_true_train, y_pred_train = [], []

        for diffs, labels in train_loader:
            diffs, labels = diffs.to(device), labels.to(device)

            optimizer.zero_grad()
            preds = pair_mlp(diffs)
            loss = criterion(preds, labels.unsqueeze(1))

            loss.backward()
            optimizer.step()

            running_loss += loss.item() * labels.size(0)
            total_train += labels.size(0)

            pred_bin = (preds > 0.5).float().squeeze()
            correct_train += (pred_bin == labels).sum().item()

            y_true_train.extend(labels.cpu().numpy())
            y_pred_train.extend(preds.detach().cpu().numpy().flatten())

        epoch_loss = running_loss / total_train
        epoch_acc = correct_train / total_train
        epoch_auc = roc_auc_score(y_true_train, y_pred_train)

        history['train_loss'].append(epoch_loss)
        history['train_acc'].append(epoch_acc)
        history['train_auc'].append(epoch_auc)

        # ---------- EVAL ----------
        pair_mlp.eval()
        total_test, correct_test = 0, 0
        test_loss = 0.0
        y_true_test, y_pred_test = [], []

        with torch.no_grad():
            for diffs, labels in test_loader:
                diffs, labels = diffs.to(device), labels.to(device)
                preds = pair_mlp(diffs)
                loss_val = criterion(preds, labels.unsqueeze(1))

                test_loss += loss_val.item() * labels.size(0)
                total_test += labels.size(0)

                pred_bin = (preds > 0.5).float().squeeze()
                correct_test += (pred_bin == labels).sum().item()

                y_true_test.extend(labels.cpu().numpy())
                y_pred_test.extend(preds.cpu().numpy().flatten())

        epoch_test_loss = test_loss / total_test
        epoch_test_acc = correct_test / total_test
        epoch_test_auc = roc_auc_score(y_true_test, y_pred_test)

        history['test_loss'].append(epoch_test_loss)
        history['test_acc'].append(epoch_test_acc)
        history['test_auc'].append(epoch_test_auc)

        print(f"Epoch [{epoch+1}/{epochs}] "
              f"Train Loss={epoch_loss:.4f}, Acc={epoch_acc*100:.2f}%, AUC={epoch_auc:.4f} | "
              f"Test Loss={epoch_test_loss:.4f}, Acc={epoch_test_acc*100:.2f}%, AUC={epoch_test_auc:.4f}")

    return history

# --------------------------------------------------
#                 MAIN
# --------------------------------------------------
if __name__ == "__main__":
    # Split the entire pairs into train/test
    X_train_pairs, X_test_pairs = train_test_split(
        all_pairs,
        test_size=0.2,
        stratify=[p[2] for p in all_pairs],
        random_state=42
    )
    print("Train pairs (split):", len(X_train_pairs))
    print("Test pairs (split):", len(X_test_pairs))

    # Build the ArcFace embeddings once (full float precision)
    # We'll store them and then do truncation in the Dataset class.
    print("Building ArcFace embeddings for train set...")
    emb_dict_train = build_embeddings_dict(X_train_pairs)
    print("Building ArcFace embeddings for test set...")
    emb_dict_test = build_embeddings_dict(X_test_pairs)

    # --------------------------------------------------
    #   1) FULL PRECISION TRAINING (e.g., decimals=None or decimals=6+)
    # --------------------------------------------------
    DECIMALS_FULL = None  # e.g. None => no truncation, or 6 => near full float precision
    print("\n=== Training with Full Precision (no truncation) ===")
    train_dataset_full = DiffLabelDataset(X_train_pairs, emb_dict_train, decimals=DECIMALS_FULL if DECIMALS_FULL else 6)
    test_dataset_full = DiffLabelDataset(X_test_pairs, emb_dict_test, decimals=DECIMALS_FULL if DECIMALS_FULL else 6)

    pair_mlp_full = PairMLP(input_dim=512, hidden_dims=[256, 128], dropout=0.3)
    EPOCHS = 5  # For demonstration, reduce or increase as needed
    hist_full = train_mlp(
        pair_mlp_full,
        train_dataset_full,
        test_dataset_full,
        epochs=EPOCHS,
        batch_size=64,
        lr=1e-3,
        alpha=0.25,
        gamma=2.0
    )

    # Plot training curves for full precision
    epochs_axis = range(1, EPOCHS+1)
    plt.figure(figsize=(18,5))

    plt.subplot(1,3,1)
    plt.plot(epochs_axis, hist_full['train_loss'], label='Train Loss')
    plt.plot(epochs_axis, hist_full['test_loss'], label='Test Loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss')
    plt.title('Full-Precision: Loss vs. Epochs')
    plt.grid(); plt.legend()

    plt.subplot(1,3,2)
    plt.plot(epochs_axis, hist_full['train_acc'], label='Train Acc')
    plt.plot(epochs_axis, hist_full['test_acc'], label='Test Acc')
    plt.xlabel('Epoch'); plt.ylabel('Accuracy')
    plt.title('Full-Precision: Accuracy vs. Epochs')
    plt.grid(); plt.legend()    

    plt.subplot(1,3,3)
    plt.plot(epochs_axis, hist_full['train_auc'], label='Train AUC')
    plt.plot(epochs_axis, hist_full['test_auc'], label='Test AUC')
    plt.xlabel('Epoch'); plt.ylabel('AUC')
    plt.title('Full-Precision: AUC vs. Epochs')
    plt.grid(); plt.legend()

    plt.tight_layout()
    plt.show()

    # --------------------------------------------------
    #   2) VARYING PRECISION: E.G. 1 TO 6 DECIMALS
    # --------------------------------------------------
    print("\n=== Evaluating performance at various decimal precisions ===")
    precisions = [1, 2, 3, 4, 5, 6]
    
    results = {
        'decimals': [],
        'test_acc': [],
        'test_auc': []
    }

    for d in precisions:
        print(f"\n--- Training with decimals={d} ---")
        # Build truncated dataset
        train_dataset_d = DiffLabelDataset(X_train_pairs, emb_dict_train, decimals=d)
        test_dataset_d = DiffLabelDataset(X_test_pairs, emb_dict_test, decimals=d)

        # New MLP for each precision
        pair_mlp_d = PairMLP(input_dim=512, hidden_dims=[256,128], dropout=0.3)
        
        # Train
        hist_d = train_mlp(
            pair_mlp_d,
            train_dataset_d,
            test_dataset_d,
            epochs=EPOCHS,
            batch_size=64,
            lr=1e-3,
            alpha=0.25,
            gamma=2.0
        )

        # Store final test metrics of last epoch
        final_test_acc = hist_d['test_acc'][-1]
        final_test_auc = hist_d['test_auc'][-1]
        results['decimals'].append(d)
        results['test_acc'].append(final_test_acc)
        results['test_auc'].append(final_test_auc)

    # --------------------------------------------------
    #   3) PLOT PRECISION vs. METRICS
    # --------------------------------------------------
    plt.figure(figsize=(12,5))

    plt.subplot(1,2,1)
    plt.plot(results['decimals'], results['test_acc'], marker='o', label='Test Accuracy')
    plt.xlabel('Decimal Precision (p)')
    plt.ylabel('Accuracy')
    plt.title('Test Accuracy vs. Decimal Precision')
    plt.grid(True)
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(results['decimals'], results['test_auc'], marker='o', color='orange', label='Test AUC')
    plt.xlabel('Decimal Precision (p)')
    plt.ylabel('AUC')
    plt.title('Test AUC vs. Decimal Precision')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Available ONNXRuntime providers: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# Using device: cpu
# Train pairs: 2200, Test pairs: 1000
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Alpha/.insightface\models\buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Alpha/.insightface\models\buffalo_l\2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Alpha/.insightface\models\buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Alpha/.insightface\models\buffalo_l\genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Alpha/.insightface\models\buffalo_l\w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (112, 112)
# Train pairs (split): 2560
# Test pairs (split): 640
# Building ArcFace embeddings for train set...
# Building ArcFace embeddings for test set...
#
# === Training with Full Precision (no truncation) ===
# Epoch [1/5] Train Loss=0.0228, Acc=85.27%, AUC=0.9266 | Test Loss=0.0363, Acc=55.16%, AUC=0.9695
# Epoch [2/5] Train Loss=0.0111, Acc=93.44%, AUC=0.9836 | Test Loss=0.0150, Acc=90.31%, AUC=0.9702
# Epoch [3/5] Train Loss=0.0071, Acc=96.45%, AUC=0.9947 | Test Loss=0.0158, Acc=90.94%, AUC=0.9680
# Epoch [4/5] Train Loss=0.0054, Acc=97.23%, AUC=0.9967 | Test Loss=0.0189, Acc=89.38%, AUC=0.9610
# Epoch [5/5] Train Loss=0.0042, Acc=97.73%, AUC=0.9983 | Test Loss=0.0226, Acc=89.53%, AUC=0.9578
# === Evaluating performance at various decimal precisions ===
#
# --- Training with decimals=1 ---
# Epoch [1/5] Train Loss=0.0273, Acc=81.29%, AUC=0.8889 | Test Loss=0.0274, Acc=84.69%, AUC=0.9550
# Epoch [2/5] Train Loss=0.0132, Acc=92.19%, AUC=0.9765 | Test Loss=0.0190, Acc=88.59%, AUC=0.9491
# Epoch [3/5] Train Loss=0.0088, Acc=95.43%, AUC=0.9905 | Test Loss=0.0224, Acc=85.78%, AUC=0.9435
# Epoch [4/5] Train Loss=0.0059, Acc=97.50%, AUC=0.9966 | Test Loss=0.0239, Acc=86.88%, AUC=0.9425
# Epoch [5/5] Train Loss=0.0041, Acc=98.12%, AUC=0.9985 | Test Loss=0.0270, Acc=85.16%, AUC=0.9386
#
# --- Training with decimals=2 ---
# Epoch [1/5] Train Loss=0.0227, Acc=84.61%, AUC=0.9263 | Test Loss=0.0367, Acc=54.69%, AUC=0.9705
# Epoch [2/5] Train Loss=0.0121, Acc=92.97%, AUC=0.9799 | Test Loss=0.0168, Acc=89.38%, AUC=0.9679
# Epoch [3/5] Train Loss=0.0075, Acc=96.09%, AUC=0.9934 | Test Loss=0.0169, Acc=89.69%, AUC=0.9645
# Epoch [4/5] Train Loss=0.0051, Acc=97.30%, AUC=0.9973 | Test Loss=0.0187, Acc=90.47%, AUC=0.9620
# Epoch [5/5] Train Loss=0.0033, Acc=98.67%, AUC=0.9993 | Test Loss=0.0242, Acc=90.00%, AUC=0.9580
#
# --- Training with decimals=3 ---
# Epoch [1/5] Train Loss=0.0234, Acc=84.84%, AUC=0.9246 | Test Loss=0.0418, Acc=51.41%, AUC=0.9711
# Epoch [2/5] Train Loss=0.0118, Acc=93.36%, AUC=0.9810 | Test Loss=0.0149, Acc=90.31%, AUC=0.9694
# Epoch [3/5] Train Loss=0.0077, Acc=95.51%, AUC=0.9929 | Test Loss=0.0169, Acc=90.31%, AUC=0.9654
# Epoch [4/5] Train Loss=0.0050, Acc=97.66%, AUC=0.9976 | Test Loss=0.0196, Acc=89.84%, AUC=0.9632
# Epoch [5/5] Train Loss=0.0036, Acc=98.28%, AUC=0.9987 | Test Loss=0.0278, Acc=87.50%, AUC=0.9567
#
# --- Training with decimals=4 ---
# Epoch [1/5] Train Loss=0.0219, Acc=85.12%, AUC=0.9318 | Test Loss=0.0334, Acc=60.62%, AUC=0.9703
# Epoch [2/5] Train Loss=0.0116, Acc=92.89%, AUC=0.9818 | Test Loss=0.0149, Acc=91.72%, AUC=0.9692
# Epoch [3/5] Train Loss=0.0073, Acc=96.13%, AUC=0.9941 | Test Loss=0.0183, Acc=90.62%, AUC=0.9668
# Epoch [4/5] Train Loss=0.0051, Acc=97.97%, AUC=0.9970 | Test Loss=0.0189, Acc=90.16%, AUC=0.9653
# Epoch [5/5] Train Loss=0.0035, Acc=98.40%, AUC=0.9990 | Test Loss=0.0202, Acc=89.38%, AUC=0.9657
#
# --- Training with decimals=5 ---
# Epoch [1/5] Train Loss=0.0243, Acc=83.87%, AUC=0.9137 | Test Loss=0.0312, Acc=67.03%, AUC=0.9730
# Epoch [2/5] Train Loss=0.0113, Acc=93.63%, AUC=0.9831 | Test Loss=0.0152, Acc=90.94%, AUC=0.9678
# Epoch [3/5] Train Loss=0.0076, Acc=95.82%, AUC=0.9933 | Test Loss=0.0189, Acc=90.31%, AUC=0.9647
# Epoch [4/5] Train Loss=0.0055, Acc=96.95%, AUC=0.9969 | Test Loss=0.0229, Acc=89.06%, AUC=0.9607
# Epoch [5/5] Train Loss=0.0038, Acc=98.09%, AUC=0.9986 | Test Loss=0.0219, Acc=88.91%, AUC=0.9615
#
# --- Training with decimals=6 ---
# Epoch [1/5] Train Loss=0.0223, Acc=86.09%, AUC=0.9311 | Test Loss=0.0570, Acc=50.00%, AUC=0.9678
# Epoch [2/5] Train Loss=0.0119, Acc=92.77%, AUC=0.9807 | Test Loss=0.0163, Acc=90.62%, AUC=0.9655
# Epoch [3/5] Train Loss=0.0078, Acc=95.78%, AUC=0.9930 | Test Loss=0.0179, Acc=90.31%, AUC=0.9629
# Epoch [4/5] Train Loss=0.0057, Acc=97.38%, AUC=0.9963 | Test Loss=0.0181, Acc=90.31%, AUC=0.9623
# Epoch [5/5] Train Loss=0.0033, Acc=98.63%, AUC=0.9994 | Test Loss=0.0241, Acc=88.44%, AUC=0.9605
